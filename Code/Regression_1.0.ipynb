# %%
# Importing Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../Source Data/data.csv')
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
#Shape of dataframe
print(" Shape of dataframe: ", df.shape)
# Out:
#  Shape of dataframe:  (18207, 89)

# %%
# Drop duplicates
df.drop_duplicates()
print(" Shape of dataframe after dropping duplicates: ", df.shape)
# Out:
#  Shape of dataframe after dropping duplicates:  (18207, 89)

# %%
#Variable inspection

print("Names of columns ", list(df.columns))
# Out:
# Names of columns  ['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position', 'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause']

# %%
df= df.drop(columns= "Unnamed: 0")

# %%
print("Names of columns ", list(df.columns))
# Out:
# Names of columns  ['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position', 'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause']

# %%
sql = "ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position', 'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'"
print(sql)
sql = sql.replace('\'', '')
print(sql)
# Out:
# ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position', 'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'
# ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value, Wage, Special, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Real Face, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, LS, ST, RS, LW, LF, CF, RF, RW, LAM, CAM, RAM, LM, LCM, CM, RCM, RM, LWB, LDM, CDM, RDM, RWB, LB, LCB, CB, RCB, RB, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause

# %%
#Null values

null= df.isnull().sum().sort_values(ascending=False)
total =df.shape[0]
percent_missing= (df.isnull().sum()/total).sort_values(ascending=False)

missing_data= pd.concat([null, percent_missing], axis=1, keys=['Total missing', 'Percent missing'])

missing_data.reset_index(inplace=True)
missing_data= missing_data.rename(columns= { "index": " column name"})
 
print ("Null Values in each column:\n", missing_data)
# Out:
# Null Values in each column:
#               column name  Total missing  Percent missing
# 0            Loaned From          16943         0.930576
# 1                    LWB           2085         0.114516
# 2                     LM           2085         0.114516
# 3                     CB           2085         0.114516
# 4                    LCB           2085         0.114516
# 5                     LB           2085         0.114516
# 6                    RWB           2085         0.114516
# 7                    RDM           2085         0.114516
# 8                    CDM           2085         0.114516
# 9                    LDM           2085         0.114516
# 10                    RM           2085         0.114516
# 11                   RCM           2085         0.114516
# 12                    CM           2085         0.114516
# 13                   LCM           2085         0.114516
# 14                   RAM           2085         0.114516
# 15                    RB           2085         0.114516
# 16                   CAM           2085         0.114516
# 17                   LAM           2085         0.114516
# 18                    RW           2085         0.114516
# 19                    RF           2085         0.114516
# 20                    CF           2085         0.114516
# 21                    LF           2085         0.114516
# 22                    LW           2085         0.114516
# 23                    RS           2085         0.114516
# 24                    ST           2085         0.114516
# 25                    LS           2085         0.114516
# 26                   RCB           2085         0.114516
# 27        Release Clause           1564         0.085901
# 28                Joined           1553         0.085297
# 29  Contract Valid Until            289         0.015873
# ..                   ...            ...              ...
# 58             Finishing             48         0.002636
# 59              Crossing             48         0.002636
# 60           Positioning             48         0.002636
# 61           LongPassing             48         0.002636
# 62           BallControl             48         0.002636
# 63          Acceleration             48         0.002636
# 64           SprintSpeed             48         0.002636
# 65            FKAccuracy             48         0.002636
# 66             Reactions             48         0.002636
# 67             ShotPower             48         0.002636
# 68            GKReflexes             48         0.002636
# 69               Jumping             48         0.002636
# 70               Stamina             48         0.002636
# 71              Strength             48         0.002636
# 72             LongShots             48         0.002636
# 73            Aggression             48         0.002636
# 74               Balance             48         0.002636
# 75         Interceptions             48         0.002636
# 76                  Flag              0         0.000000
# 77                  Name              0         0.000000
# 78                   Age              0         0.000000
# 79                 Photo              0         0.000000
# 80           Nationality              0         0.000000
# 81                 Value              0         0.000000
# 82               Overall              0         0.000000
# 83             Potential              0         0.000000
# 84             Club Logo              0         0.000000
# 85                  Wage              0         0.000000
# 86               Special              0         0.000000
# 87                    ID              0         0.000000
#
# [88 rows x 3 columns]

# %%
df_isnull = pd.isnull(df["LB"])
df[df_isnull]
# Out:
#            ID            Name  Age  \
# 3      193080          De Gea   27
# 9      200389        J. Oblak   25
# 18     192448   M. ter Stegen   26
# 19     192119     T. Courtois   26
# 22     167495        M. Neuer   32
# 37     167948       H. Lloris   31
# 40     162835   S. Handanovič   33
# 41       1179       G. Buffon   40
# 46     193041        K. Navas   31
# 57     210257         Ederson   24
# 81     212831         Alisson   25
# 92     186153     W. Szczęsny   28
# 126    199482        A. Lopes   27
# 128    198009        M. Perin   25
# 131    192563         B. Leno   26
# 133    190941     L. Hrádecký   28
# 141    178750   Sergio Asenjo   29
# 147    167628      S. Ruffier   31
# 149    163587   K. Schmeichel   31
# 177    206585            Kepa   23
# 180    204935     J. Pickford   24
# 189    200316         T. Horn   25
# 196    194404            Neto   28
# 197    193698      O. Baumann   28
# 201    192593      D. Subašić   33
# 210    179783     R. Fährmann   29
# 212    178086            Adán   31
# 213    178005    Rui Patrício   30
# 214    177683       Y. Sommer   29
# 218    163705     S. Mandanda   33
# ...       ...             ...  ...
# 18068  240286       J. García   20
# 18073  242086       M. Sutton   18
# 18074  243110       Sun Qibin   26
# 18093  244943        E. Bilen   17
# 18096  240339     J. Granlund   18
# 18097  232149       M. Connor   21
# 18101  243934       J. Hipper   19
# 18103  246240       H. Bernat   17
# 18104  243681     V. Smedsrud   18
# 18106  243685       J. Cleary   16
# 18108  245735        J. Kelly   17
# 18112  239857       Chen Zhao   21
# 18113  237045      R. Pasquel   22
# 18117  243711      T. Callens   19
# 18122  245542    G. Figliuzzi   17
# 18127  244043      N. Stephan   17
# 18128  245587    J. Greatorex   18
# 18136  237463       A. Kelsey   18
# 18143  233398        W. Henry   19
# 18145  244172      M. Harsman   18
# 18147  225510       D. Mackay   21
# 18149  245223    W. Appleyard   18
# 18158  244810        T. Lawal   18
# 18160  244817  D. Szczepaniak   18
# 18172  243636      C. Hawkins   18
# 18178  243158    L. Wahlstedt   18
# 18180  221669        M. Hurst   22
# 18183   53748   K. Pilkington   44
# 18194  245862        J. Milli   18
# 18198  242844      J. Livesey   18
#
#                                                 Photo          Nationality  \
# 3      https://cdn.sofifa.org/players/4/19/193080.png                Spain
# 9      https://cdn.sofifa.org/players/4/19/200389.png             Slovenia
# 18     https://cdn.sofifa.org/players/4/19/192448.png              Germany
# 19     https://cdn.sofifa.org/players/4/19/192119.png              Belgium
# 18106   https://cdn.sofifa.org/flags/25.png       50         72
# 18108   https://cdn.sofifa.org/flags/25.png       50         66
# 18112  https://cdn.sofifa.org/flags/155.png       50         61
# 18113   https://cdn.sofifa.org/flags/83.png       50         60
# 18117   https://cdn.sofifa.org/flags/18.png       50         65
# 18122   https://cdn.sofifa.org/flags/27.png       49         69
# 18127   https://cdn.sofifa.org/flags/21.png       49         67
# 18128   https://cdn.sofifa.org/flags/14.png       49         66
# 18136   https://cdn.sofifa.org/flags/14.png       49         65
# 18143   https://cdn.sofifa.org/flags/14.png       49         66
# 18145   https://cdn.sofifa.org/flags/21.png       49         65
# 18147   https://cdn.sofifa.org/flags/42.png       49         56
# 18149   https://cdn.sofifa.org/flags/14.png       49         65
# 18158    https://cdn.sofifa.org/flags/4.png       48         69
# 18160   https://cdn.sofifa.org/flags/37.png       48         63
# 18172   https://cdn.sofifa.org/flags/14.png       48         65
# 18178   https://cdn.sofifa.org/flags/46.png       48         65
# 18180   https://cdn.sofifa.org/flags/42.png       48         58
# 18183   https://cdn.sofifa.org/flags/14.png       48         48
# 18194   https://cdn.sofifa.org/flags/27.png       47         65
# 18198   https://cdn.sofifa.org/flags/14.png       47         70
#
#                                 Club  \
# 3                  Manchester United
# 9                    Atlético Madrid
# 18                      FC Barcelona
# 19                       Real Madrid
# 22                 FC Bayern München
# 37                 Tottenham Hotspur
# 40                             Inter
# 41               Paris Saint-Germain
# 46                       Real Madrid
# 57                   Manchester City
# 81                         Liverpool
# 92                          Juventus
# 126               Olympique Lyonnais
# 128                         Juventus
# 131                          Arsenal
# 133              Bayer 04 Leverkusen
# 141                    Villarreal CF
# 147                 AS Saint-Étienne
# 149                   Leicester City
# 177                          Chelsea
# 180                          Everton
# 189                       1. FC Köln
# 196                      Valencia CF
# 197              TSG 1899 Hoffenheim
# 201                        AS Monaco
# 210                    FC Schalke 04
# 212                  Atlético Madrid
# 213          Wolverhampton Wanderers
# 214         Borussia Mönchengladbach
# 218           Olympique de Marseille
# ...                              ...
# 18068                  Santos Laguna
# 18073              Melbourne Victory
# 18074            Tianjin Quanjian FC
# 18093                     Göztepe SK
# 18096             Sandefjord Fotball
# 18097                   Waterford FC
# 18101               TSV 1860 München
# 18103                Odense Boldklub
# 18104                    SønderjyskE
# 18106                    Bohemian FC
# 18108                 Bray Wanderers
# 18112  Shanghai Greenland Shenhua FC
# 18113               Deportivo Toluca
# 18117            Stade Malherbe Caen
# 18122                        Crotone
# 18127          FC Würzburger Kickers
# 18128                       Barnsley
# 18136              Scunthorpe United
# 18143                   Swindon Town
# 18145                      SV Meppen
# 18147                     Kilmarnock
# 18149                      Stevenage
# 18158                      LASK Linz
# 18160                      Morecambe
# 18172                  Burton Albion
# 18178                     Dalkurd FF
# 18180               St. Johnstone FC
# 18183               Cambridge United
# 18194                          Lecce
# 18198                  Burton Albion
#
#                                              Club Logo  ... Composure Marking  \
# 3          https://cdn.sofifa.org/teams/2/light/11.png  ...      68.0    15.0
# 9         https://cdn.sofifa.org/teams/2/light/240.png  ...      70.0    27.0
# 18        https://cdn.sofifa.org/teams/2/light/241.png  ...      69.0    25.0
# 19        https://cdn.sofifa.org/teams/2/light/243.png  ...      66.0    20.0
# 22         https://cdn.sofifa.org/teams/2/light/21.png  ...      70.0    17.0
# 37         https://cdn.sofifa.org/teams/2/light/18.png  ...      65.0    29.0
# 40         https://cdn.sofifa.org/teams/2/light/44.png  ...      69.0    25.0
# 41         https://cdn.sofifa.org/teams/2/light/73.png  ...      70.0    13.0
# 46        https://cdn.sofifa.org/teams/2/light/243.png  ...      67.0    28.0
# 57         https://cdn.sofifa.org/teams/2/light/10.png  ...      70.0    28.0
# 81          https://cdn.sofifa.org/teams/2/light/9.png  ...      65.0    15.0
# 92         https://cdn.sofifa.org/teams/2/light/45.png  ...      65.0    20.0
# 126        https://cdn.sofifa.org/teams/2/light/66.png  ...      65.0    13.0
# 128        https://cdn.sofifa.org/teams/2/light/45.png  ...      65.0    20.0
# 131         https://cdn.sofifa.org/teams/2/light/1.png  ...      66.0    27.0
# 133        https://cdn.sofifa.org/teams/2/light/32.png  ...      48.0    10.0
# 141       https://cdn.sofifa.org/teams/2/light/483.png  ...      64.0    24.0
# 147      https://cdn.sofifa.org/teams/2/light/1819.png  ...      66.0    13.0
# 149        https://cdn.sofifa.org/teams/2/light/95.png  ...      67.0    14.0
# 177         https://cdn.sofifa.org/teams/2/light/5.png  ...      63.0    19.0
# 180         https://cdn.sofifa.org/teams/2/light/7.png  ...      69.0    16.0
# 189        https://cdn.sofifa.org/teams/2/light/31.png  ...      20.0    14.0
# 196       https://cdn.sofifa.org/teams/2/light/461.png  ...      64.0    17.0
# 197     https://cdn.sofifa.org/teams/2/light/10029.png  ...      52.0    15.0
# 201        https://cdn.sofifa.org/teams/2/light/69.png  ...      65.0    14.0
# 210        https://cdn.sofifa.org/teams/2/light/34.png  ...      61.0    10.0
# 212       https://cdn.sofifa.org/teams/2/light/240.png  ...      63.0    20.0
# 213       https://cdn.sofifa.org/teams/2/light/110.png  ...      66.0    14.0
# 214        https://cdn.sofifa.org/teams/2/light/23.png  ...      57.0     9.0
# 218       https://cdn.sofifa.org/teams/2/light/219.png  ...      64.0    13.0
# ...                                                ...  ...       ...     ...
# 18068  https://cdn.sofifa.org/teams/2/light/110144.png  ...      31.0    21.0
# 18073  https://cdn.sofifa.org/teams/2/light/111397.png  ...      42.0     6.0
# 18074  https://cdn.sofifa.org/teams/2/light/112983.png  ...      30.0    46.0
# 18093  https://cdn.sofifa.org/teams/2/light/101026.png  ...      28.0     6.0
# 18096    https://cdn.sofifa.org/teams/2/light/1757.png  ...      31.0     7.0
# 18097     https://cdn.sofifa.org/teams/2/light/753.png  ...      36.0    11.0
# 18101      https://cdn.sofifa.org/teams/2/light/33.png  ...      25.0     7.0
# 18103     https://cdn.sofifa.org/teams/2/light/272.png  ...      37.0     6.0
# 18104    https://cdn.sofifa.org/teams/2/light/1447.png  ...      30.0    11.0
# 18106     https://cdn.sofifa.org/teams/2/light/305.png  ...      30.0     7.0
# 18108     https://cdn.sofifa.org/teams/2/light/838.png  ...      29.0     8.0
# 18112  https://cdn.sofifa.org/teams/2/light/110955.png  ...      29.0    18.0
# 18113    https://cdn.sofifa.org/teams/2/light/1882.png  ...      36.0    12.0
# 18117     https://cdn.sofifa.org/teams/2/light/210.png  ...      39.0    16.0
# 18122  https://cdn.sofifa.org/teams/2/light/110734.png  ...      36.0     6.0
# 18127  https://cdn.sofifa.org/teams/2/light/110197.png  ...      24.0    12.0
# 18128    https://cdn.sofifa.org/teams/2/light/1932.png  ...      31.0     5.0
# 18136    https://cdn.sofifa.org/teams/2/light/1949.png  ...      29.0     9.0
# 18143    https://cdn.sofifa.org/teams/2/light/1934.png  ...      35.0    11.0
# 18145  https://cdn.sofifa.org/teams/2/light/110597.png  ...      35.0     7.0
# 18147      https://cdn.sofifa.org/teams/2/light/82.png  ...      30.0    12.0
# 18149     https://cdn.sofifa.org/teams/2/light/361.png  ...      26.0     8.0
# 18158     https://cdn.sofifa.org/teams/2/light/252.png  ...      32.0     9.0
# 18160     https://cdn.sofifa.org/teams/2/light/357.png  ...      31.0     5.0
# 18172   https://cdn.sofifa.org/teams/2/light/15015.png  ...      37.0    16.0
# 18178  https://cdn.sofifa.org/teams/2/light/113876.png  ...      28.0    16.0
# 18180  https://cdn.sofifa.org/teams/2/light/100804.png  ...      28.0    12.0
# 18183    https://cdn.sofifa.org/teams/2/light/1944.png  ...      56.0    15.0
# 18194     https://cdn.sofifa.org/teams/2/light/347.png  ...      23.0     6.0
# 18198   https://cdn.sofifa.org/teams/2/light/15015.png  ...      34.0    15.0
#
#        StandingTackle SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 3                21.0          13.0      90.0        85.0       87.0
# 9                12.0          18.0      86.0        92.0       78.0
# 18               13.0          10.0      87.0        85.0       88.0
# 19               18.0          16.0      85.0        91.0       72.0
# 22               10.0          11.0      90.0        86.0       91.0
# 37               10.0          18.0      88.0        84.0       68.0
# 40               10.0          13.0      87.0        86.0       69.0
# 41               11.0          11.0      88.0        87.0       74.0
# 46               14.0          14.0      90.0        81.0       75.0
# 57               15.0           8.0      85.0        80.0       91.0
# 81               19.0          16.0      83.0        81.0       85.0
# 92               13.0          12.0      85.0        81.0       71.0
# 126              15.0          13.0      86.0        80.0       75.0
# 128              12.0          19.0      81.0        85.0       71.0
# 131              15.0          18.0      84.0        82.0       75.0
# 133              10.0          13.0      85.0        79.0       68.0
# 141              15.0          14.0      85.0        83.0       77.0
# 147              12.0          11.0      82.0        84.0       77.0
# 149              14.0          13.0      82.0        77.0       82.0
# 177              18.0          16.0      84.0        80.0       76.0
# 180              20.0          12.0      83.0        78.0       88.0
# 189              13.0          12.0      83.0        80.0       83.0
# 196              14.0          15.0      85.0        79.0       79.0
# 197              18.0          14.0      82.0        82.0       70.0
# 201              14.0          13.0      82.0        80.0       79.0
# 18073          50.0       52.0          €135K
# 18074          48.0       50.0           €45K
# 18093          41.0       50.0          €131K
# 18096          43.0       53.0           €94K
# 18097          44.0       52.0          €109K
# 18101          46.0       51.0           €50K
# 18103          51.0       52.0          €113K
# 18104          46.0       56.0           €94K
# 18106          45.0       50.0          €128K
# 18108          50.0       49.0          €109K
# 18112          40.0       53.0           €94K
# 18113          40.0       56.0           €76K
# 18117          45.0       51.0          €131K
# 18122          45.0       50.0          €130K
# 18127          49.0       54.0          €104K
# 18128          41.0       47.0          €119K
# 18136          45.0       49.0          €119K
# 18143          38.0       54.0          €119K
# 18145          44.0       48.0          €104K
# 18147          48.0       48.0           €59K
# 18149          48.0       49.0          €119K
# 18158          48.0       46.0          €147K
# 18160          50.0       49.0          €119K
# 18172          49.0       46.0          €119K
# 18178          45.0       51.0           €94K
# 18180          50.0       45.0           €78K
# 18183          49.0       46.0            NaN
# 18194          40.0       44.0          €109K
# 18198          42.0       48.0          €165K
#
# [2085 rows x 88 columns]

# %%
#Filtering data with null values for position

df_isnull = pd.isnull(df["LB"])
pos_null= df[df_isnull]
print(pos_null.shape)
print(pos_null.isnull().sum().sort_values(ascending= False))
# Out:
# (2085, 88)
# LWB                     2085
# LM                      2085
# CB                      2085
# LCB                     2085
# LB                      2085
# RWB                     2085
# RDM                     2085
# CDM                     2085
# LDM                     2085
# RM                      2085
# RCM                     2085
# CM                      2085
# LCM                     2085
# RAM                     2085
# RB                      2085
# CAM                     2085
# LAM                     2085
# RW                      2085
# RF                      2085
# CF                      2085
# LF                      2085
# LW                      2085
# RS                      2085
# ST                      2085
# LS                      2085
# RCB                     2085
# Loaned From             1996
# Release Clause           185
# Joined                   182
# Contract Valid Until      93
#                         ...
# Finishing                 48
# Interceptions             48
# FKAccuracy                48
# LongPassing               48
# BallControl               48
# Acceleration              48
# Crossing                  48
# Agility                   48
# Balance                   48
# ShotPower                 48
# GKReflexes                48
# Jumping                   48
# Stamina                   48
# Strength                  48
# LongShots                 48
# Aggression                48
# Reactions                 48
# Club                      45
# Flag                       0
# Name                       0
# Age                        0
# Photo                      0
# Nationality                0
# Wage                       0
# Overall                    0
# Potential                  0
# Club Logo                  0
# Value                      0
# Special                    0
# ID                         0
# Length: 88, dtype: int64

# %%
#Filtering relevant data & checking for club null values
df_notnull = pd.notnull(df["LB"])
df= df[df_notnull]
print(df.shape)
df.head()
# Out:
# (16122, 88)
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 4  192985       K. De Bruyne   27
# 5  183277          E. Hazard   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
# 5   https://cdn.sofifa.org/flags/7.png       91         91
#
#                   Club                                     Club Logo  ...  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png  ...
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  ...
# 4      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png  ...
# 5              Chelsea    https://cdn.sofifa.org/teams/2/light/5.png  ...
#
#   Composure Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  \
# 0      96.0    33.0            28.0          26.0       6.0        11.0
# 1      95.0    28.0            31.0          23.0       7.0        11.0
# 2      94.0    27.0            24.0          33.0       9.0         9.0
# 4      88.0    68.0            58.0          51.0      15.0        13.0
# 5      91.0    34.0            27.0          22.0      11.0        12.0
#
#    GKKicking GKPositioning GKReflexes Release Clause
# 0       15.0          14.0        8.0        €226.5M
# 1       15.0          14.0       11.0        €127.1M
# 2       15.0          15.0       11.0        €228.1M
# 4        5.0          10.0       13.0        €196.4M
# 5        6.0           8.0        8.0        €172.1M
#
# [5 rows x 88 columns]

# %%
df_isnull = pd.isnull(df["Club"])
pos_null= df[df_isnull]
print(pos_null.shape)
print(pos_null.isnull().sum().sort_values(ascending= False))
# Out:
# (196, 88)
# Release Clause          196
# Club                    196
# Contract Valid Until    196
# Joined                  196
# Loaned From             196
# LM                        0
# LW                        0
# RCM                       0
# Height                    0
# Weight                    0
# LS                        0
# ST                        0
# RS                        0
# LF                        0
# RAM                       0
# CF                        0
# CM                        0
# RW                        0
# LCM                       0
# LAM                       0
# CAM                       0
# RF                        0
# Jersey Number             0
# GKReflexes                0
# Value                     0
# Name                      0
# Age                       0
# Photo                     0
# Nationality               0
# Flag                      0
#                        ...
# Marking                   0
# StandingTackle            0
# SlidingTackle             0
# GKDiving                  0
# GKHandling                0
# GKKicking                 0
# GKPositioning             0
# Balance                   0
# Agility                   0
# CDM                       0
# Finishing                 0
# RDM                       0
# RWB                       0
# LB                        0
# LCB                       0
# CB                        0
# RCB                       0
# RB                        0
# Crossing                  0
# HeadingAccuracy           0
# SprintSpeed               0
# ShortPassing              0
# Volleys                   0
# Dribbling                 0
# Curve                     0
# FKAccuracy                0
# LongPassing               0
# BallControl               0
# Acceleration              0
# ID                        0
# Length: 88, dtype: int64

# %%
df_notnull = pd.notnull(df["Club"])
df= df[df_notnull]
print(df.shape)
print(df.isnull().sum().sort_values(ascending= False))
# Out:
# (15926, 88)
# Loaned From             14751
# Release Clause           1183
# Joined                   1175
# CM                          0
# LW                          0
# RCM                         0
# Contract Valid Until        0
# Height                      0
# Weight                      0
# LS                          0
# ST                          0
# RS                          0
# LF                          0
# LCM                         0
# GKReflexes                  0
# RF                          0
# RW                          0
# LAM                         0
# CAM                         0
# RAM                         0
# LM                          0
# CF                          0
# Jersey Number               0
# Position                    0
# Club Logo                   0
# Name                        0
# Age                         0
# Photo                       0
# Nationality                 0
# Flag                        0
#                         ...
# Marking                     0
# StandingTackle              0
# SlidingTackle               0
# GKDiving                    0
# GKHandling                  0
# GKKicking                   0
# GKPositioning               0
# Balance                     0
# Agility                     0
# CDM                         0
# Finishing                   0
# RDM                         0
# RWB                         0
# LB                          0
# LCB                         0
# CB                          0
# RCB                         0
# RB                          0
# Crossing                    0
# HeadingAccuracy             0
# SprintSpeed                 0
# ShortPassing                0
# Volleys                     0
# Dribbling                   0
# Curve                       0
# FKAccuracy                  0
# LongPassing                 0
# BallControl                 0
# Acceleration                0
# ID                          0
# Length: 88, dtype: int64

# %%
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 4  192985       K. De Bruyne   27
# 5  183277          E. Hazard   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
# 5   https://cdn.sofifa.org/flags/7.png       91         91
#
#                   Club                                     Club Logo  ...  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png  ...
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  ...
# 4      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png  ...
# 5              Chelsea    https://cdn.sofifa.org/teams/2/light/5.png  ...
#
#   Composure Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  \
# 0      96.0    33.0            28.0          26.0       6.0        11.0
# 1      95.0    28.0            31.0          23.0       7.0        11.0
# 2      94.0    27.0            24.0          33.0       9.0         9.0
# 4      88.0    68.0            58.0          51.0      15.0        13.0
# 5      91.0    34.0            27.0          22.0      11.0        12.0
#
#    GKKicking GKPositioning GKReflexes Release Clause
# 0       15.0          14.0        8.0        €226.5M
# 1       15.0          14.0       11.0        €127.1M
# 2       15.0          15.0       11.0        €228.1M
# 4        5.0          10.0       13.0        €196.4M
# 5        6.0           8.0        8.0        €172.1M
#
# [5 rows x 88 columns]

# %%
df = df.drop(columns=['Height'])
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 4  192985       K. De Bruyne   27
# 5  183277          E. Hazard   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
# 5   https://cdn.sofifa.org/flags/7.png       91         91
#
#                   Club                                     Club Logo  ...  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png  ...
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  ...
# 4      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png  ...
# 5              Chelsea    https://cdn.sofifa.org/teams/2/light/5.png  ...
#
#   Composure Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  \
# 0      96.0    33.0            28.0          26.0       6.0        11.0
# 1      95.0    28.0            31.0          23.0       7.0        11.0
# 2      94.0    27.0            24.0          33.0       9.0         9.0
# 4      88.0    68.0            58.0          51.0      15.0        13.0
# 5      91.0    34.0            27.0          22.0      11.0        12.0
#
#    GKKicking GKPositioning GKReflexes Release Clause
# 0       15.0          14.0        8.0        €226.5M
# 1       15.0          14.0       11.0        €127.1M
# 2       15.0          15.0       11.0        €228.1M
# 4        5.0          10.0       13.0        €196.4M
# 5        6.0           8.0        8.0        €172.1M
#
# [5 rows x 87 columns]

# %%
df["Weight"]= df["Weight"].str.split("lbs", n = 1, expand = True)
df["Weight"].astype(str).astype(int)
# Out:
# 0        159
# 1        183
# 2        150
# 4        154
# 5        163
# 6        146
# 7        190
# 8        181
# 10       176
# 11       168
# 12       172
# 13       148
# 14       159
# 15       165
# 16       196
# 17       161
# 20       168
# 21       170
# 23       154
# 24       187
# 25       161
# 26       157
# 27       185
# 28       172
# 29       130
# 30       174
# 31       168
# 32       150
# 33       176
# 34       203
#         ...
# 18171    148
# 18173    132
# 18174    161
# 18175    154
# 18176    148
# 18177    163
# 18179    163
# 18181    134
# 18182    165
# 18184    179
# 18185    159
# 18186    174
# 18187    161
# 18188    148
# 18189    165
# 18190    176
# 18191    168
# 18192    165
# 18193    146
# 18195    141
# 18196    146
# 18197    141
# 18199    150
# 18200    157
# 18201    168
# 18202    134
# 18203    170
# 18204    148
# 18205    154
# 18206    176
# Name: Weight, Length: 15926, dtype: int32

# %%
df = df.drop(columns=['Release Clause'])
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 4  192985       K. De Bruyne   27
# 5  183277          E. Hazard   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
# 5   https://cdn.sofifa.org/flags/7.png       91         91
#
#                   Club                                     Club Logo  ...  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png  ...
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  ...
# 4      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png  ...
# 5              Chelsea    https://cdn.sofifa.org/teams/2/light/5.png  ...
#
#   Penalties Composure  Marking StandingTackle  SlidingTackle  GKDiving  \
# 0      75.0      96.0     33.0           28.0           26.0       6.0
# 1      85.0      95.0     28.0           31.0           23.0       7.0
# 2      81.0      94.0     27.0           24.0           33.0       9.0
# 4      79.0      88.0     68.0           58.0           51.0      15.0
# 5      86.0      91.0     34.0           27.0           22.0      11.0
#
#    GKHandling GKKicking GKPositioning GKReflexes
# 0        11.0      15.0          14.0        8.0
# 1        11.0      15.0          14.0       11.0
# 2         9.0      15.0          15.0       11.0
# 4        13.0       5.0          10.0       13.0
# 5        12.0       6.0           8.0        8.0
#
# [5 rows x 86 columns]

# %%
df = df.drop(columns=['Value', 'Wage'])
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 4  192985       K. De Bruyne   27
# 5  183277          E. Hazard   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
# 5   https://cdn.sofifa.org/flags/7.png       91         91
#
#                   Club                                     Club Logo  ...  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png  ...
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  ...
# 4      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png  ...
# 5              Chelsea    https://cdn.sofifa.org/teams/2/light/5.png  ...
#
#    Penalties Composure  Marking  StandingTackle  SlidingTackle GKDiving  \
# 0       75.0      96.0     33.0            28.0           26.0      6.0
# 1       85.0      95.0     28.0            31.0           23.0      7.0
# 2       81.0      94.0     27.0            24.0           33.0      9.0
# 4       79.0      88.0     68.0            58.0           51.0     15.0
# 5       86.0      91.0     34.0            27.0           22.0     11.0
#
#   GKHandling GKKicking GKPositioning  GKReflexes
# 0       11.0      15.0          14.0         8.0
# 1       11.0      15.0          14.0        11.0
# 2        9.0      15.0          15.0        11.0
# 4       13.0       5.0          10.0        13.0
# 5       12.0       6.0           8.0         8.0
#
# [5 rows x 84 columns]

# %%
split= ["LS","ST","RS","LW","LF","CF","RF","RW","LAM","CAM","RAM","LM","LCM","CM","RCM","RM","LWB",
        "LDM","CDM","RDM","RWB","LB","LCB","CB","RCB","RB"]
df = df.apply(lambda x : x.str.split('+').str[0].astype(str).astype(int) if x.name in ["LS","ST","RS","LW","LF","CF","RF","RW","LAM","CAM","RAM","LM","LCM","CM","RCM","RM","LWB",
        "LDM","CDM","RDM","RWB","LB","LCB","CB","RCB","RB"] else x)
    
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 4  192985       K. De Bruyne   27
# 5  183277          E. Hazard   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
# 5   https://cdn.sofifa.org/flags/7.png       91         91
#
#                   Club                                     Club Logo  ...  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png  ...
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  ...
# 4      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png  ...
# 5              Chelsea    https://cdn.sofifa.org/teams/2/light/5.png  ...
#
#    Penalties Composure  Marking  StandingTackle  SlidingTackle GKDiving  \
# 0       75.0      96.0     33.0            28.0           26.0      6.0
# 1       85.0      95.0     28.0            31.0           23.0      7.0
# 2       81.0      94.0     27.0            24.0           33.0      9.0
# 4       79.0      88.0     68.0            58.0           51.0     15.0
# 5       86.0      91.0     34.0            27.0           22.0     11.0
#
#   GKHandling GKKicking GKPositioning  GKReflexes
# 0       11.0      15.0          14.0         8.0
# 1       11.0      15.0          14.0        11.0
# 2        9.0      15.0          15.0        11.0
# 4       13.0       5.0          10.0        13.0
# 5       12.0       6.0           8.0         8.0
#
# [5 rows x 84 columns]

# %%
df=df.fillna(0)
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 4  192985       K. De Bruyne   27
# 5  183277          E. Hazard   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
# 5   https://cdn.sofifa.org/flags/7.png       91         91
#
#                   Club                                     Club Logo  ...  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png  ...
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  ...
# 4      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png  ...
# 5              Chelsea    https://cdn.sofifa.org/teams/2/light/5.png  ...
#
#    Penalties Composure  Marking  StandingTackle  SlidingTackle GKDiving  \
# 0       75.0      96.0     33.0            28.0           26.0      6.0
# 1       85.0      95.0     28.0            31.0           23.0      7.0
# 2       81.0      94.0     27.0            24.0           33.0      9.0
# 4       79.0      88.0     68.0            58.0           51.0     15.0
# 5       86.0      91.0     34.0            27.0           22.0     11.0
#
#   GKHandling GKKicking GKPositioning  GKReflexes
# 0       11.0      15.0          14.0         8.0
# 1       11.0      15.0          14.0        11.0
# 2        9.0      15.0          15.0        11.0
# 4       13.0       5.0          10.0        13.0
# 5       12.0       6.0           8.0         8.0
#
# [5 rows x 84 columns]

# %%
unique_position= df.Position.unique()
unique_position
# Out:
# array(['RF', 'ST', 'LW', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB', 'LDM',
#        'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM', 'RW',
#        'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB'], dtype=object)

# %%
list(df.columns)
# Out:
# ['ID',
#  'Name',
#  'Age',
#  'Photo',
#  'Nationality',
#  'Flag',
#  'Overall',
#  'Potential',
#  'Club',
#  'Club Logo',
#  'Special',
#  'Preferred Foot',
#  'International Reputation',
#  'Weak Foot',
#  'Skill Moves',
#  'Work Rate',
#  'Body Type',
#  'Real Face',
#  'Position',
#  'Jersey Number',
#  'Joined',
#  'Loaned From',
#  'Contract Valid Until',
#  'Weight',
#  'LS',
#  'ST',
#  'RS',
#  'LW',
#  'LF',
#  'CF',
#  'RF',
#  'RW',
#  'LAM',
#  'CAM',
#  'RAM',
#  'LM',
#  'LCM',
#  'CM',
#  'RCM',
#  'RM',
#  'LWB',
#  'LDM',
#  'CDM',
#  'RDM',
#  'RWB',
#  'LB',
#  'LCB',
#  'CB',
#  'RCB',
#  'RB',
#  'Crossing',
#  'Finishing',
#  'HeadingAccuracy',
#  'ShortPassing',
#  'Volleys',
#  'Dribbling',
#  'Curve',
#  'FKAccuracy',
#  'LongPassing',
#  'BallControl',
#  'Acceleration',
#  'SprintSpeed',
#  'Agility',
#  'Reactions',
#  'Balance',
#  'ShotPower',
#  'Jumping',
#  'Stamina',
#  'Strength',
#  'LongShots',
#  'Aggression',
#  'Interceptions',
#  'Positioning',
#  'Vision',
#  'Penalties',
#  'Composure',
#  'Marking',
#  'StandingTackle',
#  'SlidingTackle',
#  'GKDiving',
#  'GKHandling',
#  'GKKicking',
#  'GKPositioning',
#  'GKReflexes']

# %%
#Drop unnecessary columns

df_model= df.drop(columns=['ID', 'Name', 'Photo', 'Nationality', 
                           'Flag','Club', 'Club Logo', 
                           'Special', 'Preferred Foot','Weak Foot', 
                           'Skill Moves', 'Work Rate', 'Body Type',
                           'Real Face', 'Position', 'Jersey Number', 
                           'Joined', 'Loaned From', 'Contract Valid Until',
                           'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 
                           'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM','LM', 
                           'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 
                           'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB','Crossing', 
                           'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',  
                           'Dribbling', 'Curve', 'FKAccuracy', 'BallControl', 'Acceleration',
                           'Reactions','ShotPower', 'LongShots',  'Interceptions', 'Penalties', 
                           'Marking','StandingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 
                           'GKPositioning', 'GKReflexes'])

# %%
df_model.head()
# Out:
#    Age  Overall  Potential  International Reputation  LongPassing  \
# 0   31       94         94                       5.0         87.0
# 1   33       94         94                       5.0         77.0
# 2   26       92         93                       5.0         78.0
# 4   27       91         92                       4.0         91.0
# 5   27       91         91                       4.0         83.0
#
#    SprintSpeed  Agility  Balance  Jumping  Stamina  Strength  Aggression  \
# 0         86.0     91.0     95.0     68.0     72.0      59.0        48.0
# 1         91.0     87.0     70.0     95.0     88.0      79.0        63.0
# 2         90.0     96.0     84.0     61.0     81.0      49.0        56.0
# 4         76.0     79.0     77.0     63.0     90.0      75.0        76.0
# 5         88.0     95.0     94.0     56.0     83.0      66.0        54.0
#
#    Positioning  Vision  Composure  SlidingTackle
# 0         94.0    94.0       96.0           26.0
# 1         95.0    82.0       95.0           23.0
# 2         89.0    87.0       94.0           33.0
# 4         87.0    94.0       88.0           51.0
# 5         87.0    89.0       91.0           22.0

# %%
#Split Overall as a Target value
target = df_model.Overall
df_model2 = df_model.drop(['Overall'], axis = 1)

#Splitting into test and train
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_model2, target, test_size=0.2)

#One Hot Encoding
X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)
print(X_test.shape,X_train.shape)
print(X_train.head())
print(y_test.shape,y_train.shape)
# Out:
# (3186, 15) (12740, 15)
#        Age  Potential  International Reputation  LongPassing  SprintSpeed  \
# 17126   25         57                       1.0         59.0         63.0
# 277     29         83                       2.0         70.0         59.0
# 4609    23         76                       1.0         41.0         82.0
# 8334    22         76                       1.0         64.0         84.0
# 4716    24         73                       1.0         59.0         81.0
#
#        Agility  Balance  Jumping  Stamina  Strength  Aggression  Positioning  \
# 17126     66.0     70.0     30.0     61.0      64.0        37.0         45.0
# 277       56.0     58.0     78.0     72.0      87.0        82.0         39.0
# 4609      78.0     77.0     59.0     73.0      66.0        30.0         68.0
# 8334      94.0     86.0     55.0     66.0      41.0        70.0         59.0
# 4716      70.0     82.0     50.0     72.0      78.0        63.0         63.0
#
#        Vision  Composure  SlidingTackle
# 17126    59.0       43.0           34.0
# 277      56.0       72.0           85.0
# 4609     58.0       64.0           12.0
# 8334     63.0       67.0           47.0
# 4716     72.0       62.0           48.0
# (3186,) (12740,)

# %%
#Applying Linear Regression
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
predictions = model.predict(X_test)

#Finding the r2 score and root mean squared error
from sklearn.metrics import r2_score, mean_squared_error, accuracy_score 

print('r2 score: '+str(r2_score(y_test, predictions)))
print('RMSE : '+str(np.sqrt(mean_squared_error(y_test, predictions))))
#print('Accurancy '+str(accuracy_score(y_test ,predictions)))
#print (accuracy_score (y_test ,predictions))
# Out:
# r2 score: 0.903888115021314
# RMSE : 2.121792659649741

# %%
plt.figure(figsize=(18,10))
plt.scatter(predictions, y_test)
plt.xlabel("Predictors")
plt.ylabel('Overall')
plt.title("Linear Model for Overall Rating Prediction")
plt.show()

# %%
Y = model.coef_
X = range(len(Y))
plt.bar(X,Y)
print(Y)
# Out:
# [ 0.69057675  0.67701678  0.52022815  0.04394581  0.05121139  0.0187893
#  -0.02130961  0.00871804  0.04381442  0.04461189  0.00927684  0.02439074
#  -0.01134271  0.10688599  0.00357633]

# %%
from sklearn.neighbors import KNeighborsRegressor
K = 10
model = KNeighborsRegressor(n_neighbors=K)
model.fit(X_train, y_train)
predictions = model.predict(X_test)

# %%
print('r2 score: '+str(r2_score(y_test, predictions)))
print('RMSE : '+str(np.sqrt(mean_squared_error(y_test, predictions))))
# Out:
# r2 score: 0.8978128854546312
# RMSE : 2.1878244087312058

# %%
print('Predicted weights: %s' % predictions)
print('Actual weights: %s' % y_test)
# Out:
# Predicted weights: [62.6 62.4 59.7 ... 59.  52.7 64.4]
# Actual weights: 12620    63
# 11046    64
# 16340    57
# 1899     75
# 6868     68
# 7069     68
# 14923    60
# 12611    63
# 10814    65
# 12123    63
# 9584     66
# 3108     73
# 16782    56
# 15177    60
# 11920    64
# 8699     67
# 12687    63
# 6718     68
# 5981     69
# 13054    63
# 2361     74
# 3065     73
# 4405     71
# 11787    64
# 11713    64
# 7467     68
# 14867    60
# 12070    63
# 4232     71
# 5743     69
#          ..
# 16930    56
# 7284     68
# 1174     77
# 6766     68
# 1138     77
# 6247     69
# 989      77
# 3651     72
# 15979    58
# 2787     73
# 2369     74
# 621      79
# 8003     67
# 13916    62
# 2692     73
# 11890    64
# 9710     66
# 7237     68
# 12486    63
# 878      78
# 14031    61
# 14562    61
# 9492     66
# 12249    63
# 11361    64
# 10844    65
# 8688     67
# 16085    58
# 18054    50
# 13068    62
# Name: Overall, Length: 3186, dtype: int64

# %%
score_list = []
param_test = {'n_neighbors': np.arange(3, 30, 1)}
Gs = GridSearchCV(estimator=KNeighborsRegressor(weights='uniform'),
                  param_grid=param_test, scoring='neg_mean_squared_error', cv=5)  
Gs.fit(X_train, y_train)
score_list = -Gs.cv_results_['mean_test_score']  # 取反,损失是负数
plt.figure(figsize=[8, 6])
plt.plot(range(3, 30, 1), score_list)
plt.xlabel("k", fontsize=15)
plt.ylabel("MSE", fontsize=15)
plt.title("best_k", fontsize=30)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-08b4e2aa5807> in <module>
#       1 score_list = []
#       2 param_test = {'n_neighbors': np.arange(3, 30, 1)}
# ----> 3 Gs = GridSearchCV(estimator=KNeighborsRegressor(weights='uniform'),
#       4                   param_grid=param_test, scoring='neg_mean_squared_error', cv=5)
#       5 Gs.fit(X_train, y_train)
#
# NameError: name 'GridSearchCV' is not defined

# %%
Gs.best_estimator_
Gs.best_score_
Gs.best_params_
# Out:
# {'n_neighbors': 13}

# %%
K = 13
model = KNeighborsRegressor(n_neighbors=K, weights='uniform')
model.fit(X_train, y_train)
predictions = model.predict(X_test)

print('r2 score: '+str(r2_score(y_test, predictions)))
print('RMSE : '+str(np.sqrt(mean_squared_error(y_test, predictions))))
# Out:
# r2 score: 0.8934520533537382
# RMSE : 2.2290397601188303
